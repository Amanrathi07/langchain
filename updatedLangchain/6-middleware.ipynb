# %% [markdown]
# #### Middleware

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langgraph.checkpoint.memory import InMemorySaver
from langchain_core.messages import HumanMessage , SystemMessage

agent = create_agent(
    model="google_genai:gemini-3.5-flash",
    checkpointer=InMemorySaver() ,
    middleware=[
        SummarizationMiddleware(
            model="google_genai:gemini-3.5-flash",
            trigger=("messages",10),
            keep=("messages",4)
        )
    ]
)

# %%
config = {"configurable":{"thread_id":"test-1"}}

questions = [
    "What is 2+2?",
    "What is 5+3?",
    "What is 10-4?",
    "What is 6*2?",
    "What is 15/3?",
    "What is 9+7?"
]

# %%
for q in questions:
    response = agent.invoke({
        "messages":[HumanMessage(
            content=q
        )] 
    },config)

    print(f"messages:{response}")
    print(f"messages:{len(response["messages"])}")
# Out:
# messages:{'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='d5a52142-ea6d-40dd-90cd-f2d9e186075c'), AIMessage(content=[{'type': 'text', 'text': '2 + 2 is 4.', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f5309-a3f5-7e73-860b-6be23635522b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 79, 'total_tokens': 87, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 71}})]}
# messages:2
# messages:{'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='d5a52142-ea6d-40dd-90cd-f2d9e186075c'), AIMessage(content=[{'type': 'text', 'text': '2 + 2 is 4.', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f5309-a3f5-7e73-860b-6be23635522b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 79, 'total_tokens': 87, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 71}}), HumanMessage(content='What is 5+3?', additional_kwargs={}, response_metadata={}, id='0d0ec8cf-6dce-424b-9d04-4f96504bf745'), AIMessage(content=[{'type': 'text', 'text': '5 + 3 is 8.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f5309-c0b2-7553-b034-b8706f860496-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 96, 'output_tokens': 87, 'total_tokens': 183, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 79}})]}
# messages:4
# messages:{'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='d5a52142-ea6d-40dd-90cd-f2d9e186075c'), AIMessage(content=[{'type': 'text', 'text': '2 + 2 is 4.', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f5309-a3f5-7e73-860b-6be23635522b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 79, 'total_tokens': 87, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 71}}), HumanMessage(content='What is 5+3?', additional_kwargs={}, response_metadata={}, id='0d0ec8cf-6dce-424b-9d04-4f96504bf745'), AIMessage(content=[{'type': 'text', 'text': '5 + 3 is 8.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f5309-c0b2-7553-b034-b8706f860496-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 96, 'output_tokens': 87, 'total_tokens': 183, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 79}}), HumanMessage(content='What is 10-4?', additional_kwargs={}, response_metadata={}, id='adff988e-e248-4656-8279-93678fce4dd8'), AIMessage(content=[{'type': 'text', 'text': '10 - 4 is 6.', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f5309-d523-7720-a946-14044be0e742-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 193, 'output_tokens': 83, 'total_tokens': 276, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 74}})]}
# messages:6
# messages:{'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='d5a52142-ea6d-40dd-90cd-f2d9e186075c'), AIMessage(content=[{'type': 'text', 'text': '2 + 2 is 4.', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f5309-a3f5-7e73-860b-6be23635522b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 79, 'total_tokens': 87, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 71}}), HumanMessage(content='What is 5+3?', additional_kwargs={}, response_metadata={}, id='0d0ec8cf-6dce-424b-9d04-4f96504bf745'), AIMessage(content=[{'type': 'text', 'text': '5 + 3 is 8.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f5309-c0b2-7553-b034-b8706f860496-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 96, 'output_tokens': 87, 'total_tokens': 183, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 79}}), HumanMessage(content='What is 10-4?', additional_kwargs={}, response_metadata={}, id='adff988e-e248-4656-8279-93678fce4dd8'), AIMessage(content=[{'type': 'text', 'text': '10 - 4 is 6.', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f5309-d523-7720-a946-14044be0e742-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 193, 'output_tokens': 83, 'total_tokens': 276, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 74}}), HumanMessage(content='What is 6*2?', additional_kwargs={}, response_metadata={}, id='dd5192af-eae3-449b-929c-fde53aaefe73'), AIMessage(content=[{'type': 'text', 'text': '6 * 2 is 12.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f5309-e8db-77f2-a325-188432d62a09-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 285, 'output_tokens': 87, 'total_tokens': 372, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 78}})]}
# messages:8
# messages:{'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='d5a52142-ea6d-40dd-90cd-f2d9e186075c'), AIMessage(content=[{'type': 'text', 'text': '2 + 2 is 4.', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f5309-a3f5-7e73-860b-6be23635522b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 79, 'total_tokens': 87, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 71}}), HumanMessage(content='What is 5+3?', additional_kwargs={}, response_metadata={}, id='0d0ec8cf-6dce-424b-9d04-4f96504bf745'), AIMessage(content=[{'type': 'text', 'text': '5 + 3 is 8.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f5309-c0b2-7553-b034-b8706f860496-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 96, 'output_tokens': 87, 'total_tokens': 183, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 79}}), HumanMessage(content='What is 10-4?', additional_kwargs={}, response_metadata={}, id='adff988e-e248-4656-8279-93678fce4dd8'), AIMessage(content=[{'type': 'text', 'text': '10 - 4 is 6.', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f5309-d523-7720-a946-14044be0e742-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 193, 'output_tokens': 83, 'total_tokens': 276, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 74}}), HumanMessage(content='What is 6*2?', additional_kwargs={}, response_metadata={}, id='dd5192af-eae3-449b-929c-fde53aaefe73'), AIMessage(content=[{'type': 'text', 'text': '6 * 2 is 12.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f5309-e8db-77f2-a325-188432d62a09-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 285, 'output_tokens': 87, 'total_tokens': 372, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 78}}), HumanMessage(content='What is 15/3?', additional_kwargs={}, response_metadata={}, id='5919d001-da62-4b98-bd77-cb81555b6e8c'), AIMessage(content=[{'type': 'text', 'text': '15 / 3 is 5.', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_rat ...
# messages:10
# messages:{'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n## SESSION INTENT\n\nThe user\'s primary goal is to obtain answers to a series of basic arithmetic questions.\n\n## SUMMARY\n\nThe conversation consists of a sequence of simple mathematical queries and their respective answers:\n- User asked "What is 2+2?", AI answered "4".\n- User asked "What is 5+3?", AI answered "8".\n- User asked "What is 10-4?", AI answered "6".\n- The latest query from the user is "What is 6*2?", which has not yet been answered.\n\n## ARTIFACTS\n\nNone\n\n## NEXT STEPS\n\n- Calculate and provide the answer to the user\'s latest query: "What is 6*2?" (12).', additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='6a074be9-5ac2-483f-8cda-eb479e741dc7'), AIMessage(content=[{'type': 'text', 'text': '6 * 2 is 12.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f5309-e8db-77f2-a325-188432d62a09-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 285, 'output_tokens': 87, 'total_tokens': 372, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 78}}), HumanMessage(content='What is 15/3?', additional_kwargs={}, response_metadata={}, id='5919d001-da62-4b98-bd77-cb81555b6e8c'), AIMessage(content=[{'type': 'text', 'text': '15 / 3 is 5.', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f530a-0056-7f52-a12d-9ca4aa7b7b93-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 382, 'output_tokens': 86, 'total_tokens': 468, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 77}}), HumanMessage(content='What is 9+7?', additional_kwargs={}, response_metadata={}, id='d5348b51-1644-4537-826f-2134f10ab489'), AIMessage(content=[{'type': 'text', 'text': '9 + 7 is 16.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f530a-41e7-7492-be02-10c4a6edf26a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 362, 'output_tokens': 90, 'total_tokens': 452, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 81}})]}
# messages:6
